# %% [markdown]
# <center>
#     <h1>Mohamed Nasser Aboelnasr</h1>
# </center>

# %%
# helping libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **- Inspecting and cleaning Dataset**

# %%
df = pd.read_csv("weatherHistory.csv")

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.head(10)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
# 6                  5.522222      0.95            12.3648
# 7                  6.527778      0.89            14.1519
# 8                 10.822222      0.82            11.3183
# 9                 13.772222      0.72            12.5258
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
# 5                   258.0          14.9569         0.0               1016.66
# 6                   259.0           9.9820         0.0               1016.72
# 7                   260.0           9.9820         0.0               1016.84
# 8                   259.0           9.9820         0.0               1017.37
# 9                   279.0           9.9820         0.0               1017.22
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# 5  Partly cloudy throughout the day.
# 6  Partly cloudy throughout the day.
# 7  Partly cloudy throughout the day.
# 8  Partly cloudy throughout the day.
# 9  Partly cloudy throughout the day.

# %%
df.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.

# %%
df.describe().T
# Out:
#                             count         mean         std        min  \
# Temperature (C)           96453.0    11.932678    9.551546 -21.822222
# Apparent Temperature (C)  96453.0    10.855029   10.696847 -27.716667
# Humidity                  96453.0     0.734899    0.195473   0.000000
# Wind Speed (km/h)         96453.0    10.810640    6.913571   0.000000
# Wind Bearing (degrees)    96453.0   187.509232  107.383428   0.000000
# Visibility (km)           96453.0    10.347325    4.192123   0.000000
# Loud Cover                96453.0     0.000000    0.000000   0.000000
# Pressure (millibars)      96453.0  1003.235956  116.969906   0.000000
#
#                                   25%        50%          75%          max
# Temperature (C)              4.688889    12.0000    18.838889    39.905556
# Apparent Temperature (C)     2.311111    12.0000    18.838889    39.344444
# Humidity                     0.600000     0.7800     0.890000     1.000000
# Wind Speed (km/h)            5.828200     9.9659    14.135800    63.852600
# Wind Bearing (degrees)     116.000000   180.0000   290.000000   359.000000
# Visibility (km)              8.339800    10.0464    14.812000    16.100000
# Loud Cover                   0.000000     0.0000     0.000000     0.000000
# Pressure (millibars)      1011.900000  1016.4500  1021.090000  1046.380000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.isna().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)

# %%
df.isna().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns:
  print(df[col].value_counts())
  print('######################################################')
# Out:
# 2011-02-08 22:00:00.000 +0100    1
# 2009-05-21 18:00:00.000 +0200    1
# 2015-05-25 19:00:00.000 +0200    1
# 2007-03-09 19:00:00.000 +0100    1
# 2007-03-14 21:00:00.000 +0100    1
#                                 ..
# 2016-06-21 10:00:00.000 +0200    1
# 2013-10-26 10:00:00.000 +0200    1
# 2013-02-16 05:00:00.000 +0100    1
# 2016-08-02 01:00:00.000 +0200    1
# 2008-05-02 12:00:00.000 +0200    1
# Name: Formatted Date, Length: 96429, dtype: int64
# ######################################################
# Partly Cloudy                          31726
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10873
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# Windy                                      8
# Humid and Overcast                         7
# Windy and Foggy                            4
# Dangerously Windy and Partly Cloudy        1
# Breezy and Dry                             1
# Windy and Dry                              1
# Name: Summary, dtype: int64
# ######################################################
# rain    85717
# snow    10712
# Name: Precip Type, dtype: int64
# ######################################################
#  7.222222     455
#  7.777778     408
#  12.777778    378
#  17.777778    373
#  6.111111     370
#              ...
# -8.466667       1
#  28.194444      1
#  32.816667      1
# -6.655556       1
# -11.533333      1
# Name: Temperature (C), Length: 7574, dtype: int64
# ######################################################
#  12.777778    378
#  17.777778    373
#  13.888889    342
#  17.222222    330
#  12.222222    305
#              ...
# -25.922222      1
#  24.322222      1
#  34.277778      1
#  29.550000      1
#  21.816667      1
# Name: Apparent Temperature (C), Length: 8984, dtype: int64
# ######################################################
# 0.93    5707
# 0.92    3887
# 0.96    3843
# 1.00    2889
# 0.89    2837
#         ...
# 0.15      10
# 0.16       8
# 0.14       4
# 0.12       1
# 0.13       1
# Name: Humidity, Length: 90, dtype: int64
# ######################################################
# 3.2200     2440
# 11.2700    1494
# 6.4400     1355
# 0.0000     1296
# 8.0500      920
#            ...
# 37.5774       1
# 37.9799       1
# 37.8028       1
# 39.8314       1
# 31.2179       1
# Name: Wind Speed (km/h), Length: 2484, dtype: int64
# ######################################################
# 0.0      2262
# 150.0    1799
# 160.0    1631
# 140.0    1509
# 310.0    1451
#          ...
# 74.0       52
# 95.0       48
# 83.0       48
# 86.0       47
# 94.0       44
# Name: Wind Bearing (degrees), Length: 360, dtype: int64
# ######################################################
# 9.9820     18277
# 16.1000     7092
# 15.8263     5683
# 11.2700     4580
# 10.3523     3536
#            ...
# 14.1841        1
# 11.7208        1
# 13.9265        1
# 15.5687        1
# 13.0410        1
# Name: Visibility (km), Length: 949, dtype: int64
# ######################################################
# 0.0    96429
# Name: Loud Cover, dtype: int64
# ######################################################
# 0.00       1288
# 1017.70     123
# 1015.00     119
# 1018.00     118
# 1015.80     118
#            ...
# 993.14        1
# 990.97        1
# 1040.11       1
# 997.83        1
# 992.29        1
# Name: Pressure (millibars), Length: 4979, dtype: int64
# ######################################################
# Mostly cloudy throughout the day.                                                            20085
# Partly cloudy throughout the day.                                                             9981
# Partly cloudy until night.                                                                    6169
# Partly cloudy starting in the morning.                                                        5184
# Foggy in the morning.                                                                         4201
#                                                                                              ...
# Drizzle starting in the evening.                                                                24
# Mostly cloudy until evening and windy starting in the morning continuing until afternoon.       24
# Partly cloudy starting overnight and breezy in the afternoon.                                   24
# Mostly cloudy starting in the morning and breezy in the evening.                                24
# Foggy starting overnight continuing until morning and breezy in the afternoon.                  23
# Name: Daily Summary, Length: 214, dtype: int64
# ######################################################

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
sns.set_style("darkgrid")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
for col in df.columns.difference(["Formatted Date", "Summary", "Precip Type", "Daily Summary"]):
  ax = sns.pairplot(data=df, x_vars=col, y_vars=["Apparent Temperature (C)"], height=6, aspect=9/5, hue='Precip Type')

# %% [markdown]
# <hr>

# %% [markdown]
# # **- Playing with features**

# %%
_ = df.rename(columns={"Formatted Date": "Date"}, inplace=True)

# %%
 df['Date'] = pd.to_datetime(df['Date'], utc=True)

# %%
df.dtypes
# Out:
# Date                        datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
df['Hour'] = df.Date.dt.hour
df['Month'] = df.Date.dt.month
df['Year'] = df.Date.dt.year

# %%
df.drop(['Loud Cover', 'Daily Summary', 'Date'], axis=1, inplace=True)

# %%
precip_cols = pd.get_dummies(df['Precip Type'], prefix='precip_')

# %%
df = df.drop('Precip Type',axis = 1)
df = df.join(precip_cols)

# %%
most_important_summaries = list((df['Summary'].value_counts()[:8]).index)

# %%
most_important_summaries
# Out:
# ['Partly Cloudy',
#  'Mostly Cloudy',
#  'Overcast',
#  'Clear',
#  'Foggy',
#  'Breezy and Overcast',
#  'Breezy and Mostly Cloudy',
#  'Breezy and Partly Cloudy']

# %%
unwanted_summaries = np.invert(df.Summary.isin(most_important_summaries))

df.drop(df[unwanted_summaries].index, inplace=True)

# %%
df.shape
# Out:
# (95868, 13)

# %%
summary_cols = pd.get_dummies(df['Summary'], prefix='summary')
df = df.drop('Summary',axis = 1)
df = df.join(summary_cols)

# %%
df.shape
# Out:
# (95868, 20)

# %%
df.columns
# Out:
# Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Pressure (millibars)', 'Hour', 'Month', 'Year', 'precip__rain',
#        'precip__snow', 'summary_Breezy and Mostly Cloudy',
#        'summary_Breezy and Overcast', 'summary_Breezy and Partly Cloudy',
#        'summary_Clear', 'summary_Foggy', 'summary_Mostly Cloudy',
#        'summary_Overcast', 'summary_Partly Cloudy'],
#       dtype='object')

# %%
(df['Pressure (millibars)'] == 0.0).sum()
# Out:
# 1252

# %%
df['Pressure (millibars)'] = df['Pressure (millibars)'].replace(0.0, np.nan).fillna(method='ffill')

# %%
(df['Pressure (millibars)'] == 0.0).sum()
# Out:
# 0

# %% [markdown]
# # **- Handling features and Taking Decisions**

# %%
df.columns
# Out:
# Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Pressure (millibars)', 'Hour', 'Month', 'Year', 'precip__rain',
#        'precip__snow', 'summary_Breezy and Mostly Cloudy',
#        'summary_Breezy and Overcast', 'summary_Breezy and Partly Cloudy',
#        'summary_Clear', 'summary_Foggy', 'summary_Mostly Cloudy',
#        'summary_Overcast', 'summary_Partly Cloudy'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
target_cols =  df.columns.difference(['Date', 'Apparent Temperature (C)', 'Hour', 'Month', 'Year', 'precip__rain',
       'precip__snow', 'summary_Breezy and Mostly Cloudy',
       'summary_Breezy and Overcast', 'summary_Breezy and Partly Cloudy',
       'summary_Clear', 'summary_Foggy', 'summary_Mostly Cloudy',
       'summary_Overcast', 'summary_Partly Cloudy'])

plt.figure(figsize=(15,7))
_ = sns.boxplot(data=scaled_df[target_cols], width=0.8)
plt.xticks(rotation=90)
plt.show()

# %%
corr= df[list(target_cols)+['Apparent Temperature (C)']].corr()

# Getting the Upper Triangle of the co-relation matrix
matrix = np.triu(corr)

# using the upper triangle matrix as mask 
sns.set()
plt.figure(figsize=(12,6))
sns.heatmap(corr, annot=True, mask=matrix)
plt.show()

# %%
corr= df.corr()

# Getting the Upper Triangle of the co-relation matrix
matrix = np.triu(corr)

# using the upper triangle matrix as mask 
sns.set()
plt.figure(figsize=(18,8))
sns.heatmap(corr, annot=True, mask=matrix)
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# # **- Implementing different regression models**

# %%
from sklearn.svm import SVR
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## **1) Simple Linear Regression**

# %% [markdown]
# >## **Choosing most correlated feature**

# %%
X = np.array(df['Temperature (C)']).reshape(-1,1)
y = df['Apparent Temperature (C)']

# %%
linear_model = LinearRegression()
linear_model.fit(X,y)
linear_model.score(X,y)
# Out:
# 0.9855153892306606

# %%
print(linear_model.intercept_)
print(linear_model.coef_)
# Out:
# -2.398764352544873
# [1.11142614]

# %%
Xs = sm.add_constant(X)
results = sm.OLS(y, Xs).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.986
# Model:                                  OLS   Adj. R-squared:                  0.986
# Method:                       Least Squares   F-statistic:                 6.523e+06
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:40:02   Log-Likelihood:            -1.6016e+05
# No. Observations:                     95868   AIC:                         3.203e+05
# Df Residuals:                         95866   BIC:                         3.203e+05
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.3988      0.007   -361.063      0.000      -2.412      -2.386
# x1             1.1114      0.000   2553.939      0.000       1.111       1.112
# ==============================================================================
# Omnibus:                     3712.111   Durbin-Watson:                   0.391
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4791.708
# Skew:                          -0.421   Prob(JB):                         0.00
# Kurtosis:                       3.701   Cond. No.                         24.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# > ### **f-statistic and p-value are good.**

# %% [markdown]
# >## **Trying another feature**

# %%
X = np.array(df['Humidity']).reshape(-1,1)

# %%
linear_model = LinearRegression()
linear_model.fit(X,y)
linear_model.score(X,y)
# Out:
# 0.3636015267028274

# %%
print(linear_model.intercept_)
print(linear_model.coef_)
# Out:
# 35.18345379637249
# [-33.09202969]

# %%
Xs = sm.add_constant(X)
results = sm.OLS(y, Xs).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.364
# Model:                                  OLS   Adj. R-squared:                  0.364
# Method:                       Least Squares   F-statistic:                 5.477e+04
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:40:02   Log-Likelihood:            -3.4148e+05
# No. Observations:                     95868   AIC:                         6.830e+05
# Df Residuals:                         95866   BIC:                         6.830e+05
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.1835      0.108    327.026      0.000      34.973      35.394
# x1           -33.0920      0.141   -234.035      0.000     -33.369     -32.815
# ==============================================================================
# Omnibus:                     3397.649   Durbin-Watson:                   0.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3768.353
# Skew:                          -0.479   Prob(JB):                         0.00
# Kurtosis:                       3.159   Cond. No.                         7.98
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# > ### **statistics are good but score is very low.**

# %% [markdown]
# > # **Trying 3 models with different features each time**

# %% [markdown]
# # **A) Temperature, Humidity, Visibility**

# %%
features = ['Temperature (C)', 'Humidity', 'Visibility (km)']

# %% [markdown]
# ## **2) Multiple Linear Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
multiple_model = LinearRegression()
multiple_model.fit(X,y)
multiple_model.score(X,y)
# Out:
# 0.9865497596474742

# %%
print(multiple_model.intercept_)
print(multiple_model.coef_)
# Out:
# -1.898911205391119e-17
# [ 1.01993781  0.04033619 -0.00431579]

# %%
Xs = sm.add_constant(X)
results = sm.OLS(y, Xs).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.987
# Model:                                  OLS   Adj. R-squared:                  0.987
# Method:                       Least Squares   F-statistic:                 2.344e+06
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:40:03   Log-Likelihood:                 70505.
# No. Observations:                     95868   AIC:                        -1.410e+05
# Df Residuals:                         95864   BIC:                        -1.410e+05
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            9.476e-17      0.000   2.53e-13      1.000      -0.001       0.001
# Temperature (C)     1.0199      0.000   2056.671      0.000       1.019       1.021
# Humidity            0.0403      0.000     82.209      0.000       0.039       0.041
# Visibility (km)    -0.0043      0.000    -10.435      0.000      -0.005      -0.004
# ==============================================================================
# Omnibus:                     1720.114   Durbin-Watson:                   0.414
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2973.417
# Skew:                          -0.149   Prob(JB):                         0.00
# Kurtosis:                       3.810   Cond. No.                         2.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## **3) Polynomial Regression**

# %%
poly2 = PolynomialFeatures(degree=2)
poly4 = PolynomialFeatures(degree=4)

x1 = scaled_df['Temperature (C)']
x2 = poly4.fit_transform(np.array(scaled_df['Visibility (km)']).reshape(-1,1))
x3 = poly2.fit_transform(np.array(scaled_df['Humidity']).reshape(-1,1))

# %%
X = np.c_[x1,x2,-x3]

# %%
X = pd.DataFrame(X, columns=['temp', 'vis0', 'vis1', 'vis2', 'vis3', 'vis4', 'hum0', 'hum1', 'hum2'])

# %%
polynomial_model = LinearRegression(False)
polynomial_model.fit(X,y)
polynomial_model.score(X,y)
# Out:
# /home/mnasser/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass fit_intercept=False as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# 0.9868217135421061

# %%
print(polynomial_model.intercept_)
print(polynomial_model.coef_)
# Out:
# 0.0
# [ 1.02413435e+00  7.10712927e-04  1.95346729e-04  1.20524320e-02
#  -3.32574586e-03 -8.69142623e-04 -7.10712927e-04 -2.75632257e-02
#   1.27528860e-02]

# %%
results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.987
# Model:                                  OLS   Adj. R-squared:                  0.987
# Method:                       Least Squares   F-statistic:                 1.025e+06
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:40:03   Log-Likelihood:                 71484.
# No. Observations:                     95868   AIC:                        -1.430e+05
# Df Residuals:                         95860   BIC:                        -1.429e+05
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# temp           1.0241      0.001   2028.148      0.000       1.023       1.025
# vis0           0.0007      0.000      2.269      0.023    9.67e-05       0.001
# vis1           0.0002      0.002      0.122      0.903      -0.003       0.003
# vis2           0.0121      0.001     12.268      0.000       0.010       0.014
# vis3          -0.0033      0.001     -3.573      0.000      -0.005      -0.002
# vis4          -0.0009      0.000     -2.051      0.040      -0.002   -3.85e-05
# hum0          -0.0007      0.000     -2.269      0.023      -0.001   -9.67e-05
# hum1          -0.0276      0.001    -45.281      0.000      -0.029      -0.026
# hum2           0.0128      0.000     30.584      0.000       0.012       0.014
# ==============================================================================
# Omnibus:                     1872.658   Durbin-Watson:                   0.427
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3600.816
# Skew:                          -0.120   Prob(JB):                         0.00
# Kurtosis:                       3.919   Cond. No.                     2.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.48e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## **4) Support Vector Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
svr_model = SVR(kernel='linear', C=1.0, epsilon=0.2)
svr_model.fit(X,y)
svr_model.score(X,y)
# Out:
# 0.9836438004123774

# %%
print(svr_model.intercept_)
print(svr_model.coef_)
# Out:
# [-0.03920789]
# [[ 0.98360974  0.02185406 -0.02158693]]

# %%
M = X.shape[1] # number of columns
N = len(df) # number of rows
R2 = svr_model.score(X,y)

# %%
R2_adj = 1-(1-R2)*((N-1) / (N-M-1))
R2_adj
# Out:
# 0.9836432885560105

# %% [markdown]
# > ### **Model 2 and 4 can be used.**

# %% [markdown]
# # **B) Temperature, Humidity, Visibility, Pressure, Precip Type**

# %%
features = ['Temperature (C)', 'Humidity', 'Visibility (km)', 'Pressure (millibars)', 'precip__rain', 'precip__snow']

# %% [markdown]
# > # **Using models 2 & 4**

# %% [markdown]
# ## **2) Multiple Linear Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
multiple_model = LinearRegression()
multiple_model.fit(X,y)
multiple_model.score(X,y)
# Out:
# 0.9873254612464532

# %%
print(multiple_model.intercept_)
print(multiple_model.coef_)
# Out:
# 4.633706376503188e-18
# [ 1.0291895   0.04727701 -0.00238108  0.03023004  0.00340704 -0.00340704]

# %%
Xs = sm.add_constant(X)
results = sm.OLS(y, Xs).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.987
# Model:                                  OLS   Adj. R-squared:                  0.987
# Method:                       Least Squares   F-statistic:                 1.493e+06
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:41:19   Log-Likelihood:                 73353.
# No. Observations:                     95868   AIC:                        -1.467e+05
# Df Residuals:                         95862   BIC:                        -1.466e+05
# Df Model:                                 5
# Covariance Type:                  nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 9.476e-17      0.000   2.61e-13      1.000      -0.001       0.001
# Temperature (C)          1.0292      0.001   1759.610      0.000       1.028       1.030
# Humidity                 0.0473      0.000     94.881      0.000       0.046       0.048
# Visibility (km)         -0.0024      0.000     -5.839      0.000      -0.003      -0.002
# Pressure (millibars)     0.0302      0.000     76.314      0.000       0.029       0.031
# precip__rain             0.0034      0.000     14.911      0.000       0.003       0.004
# precip__snow            -0.0034      0.000    -14.911      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                     1228.083   Durbin-Watson:                   0.440
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2202.645
# Skew:                          -0.050   Prob(JB):                         0.00
# Kurtosis:                       3.736   Cond. No.                     5.18e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.09e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## **4) Support Vector Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
svr_model = SVR(kernel='linear', C=1.0, epsilon=0.2)
svr_model.fit(X,y)
svr_model.score(X,y)
# Out:
# 0.9860912977208081

# %%
print(svr_model.intercept_)
print(svr_model.coef_)
# Out:
# [-0.02469582]
# [[ 1.01488516  0.03671279 -0.01373375  0.02879617 -0.00250628  0.00250628]]

# %%
M = X.shape[1] # number of columns
N = len(df) # number of rows
R2 = svr_model.score(X,y)

# %%
R2_adj = 1-(1-R2)*((N-1) / (N-M-1))
R2_adj
# Out:
# 0.9860904271664254

# %% [markdown]
# > ### **There is a slight difference in score between both models in favor of model 2.**

# %% [markdown]
# # **C) Temperature, Humidity, Visibility, Pressure, Precip Type, Hour, Month, Year**

# %%
features = ['Temperature (C)', 'Humidity', 'Visibility (km)', 'Pressure (millibars)', 'precip__rain', 'precip__snow', 'Hour', 'Month', 'Year']

# %% [markdown]
# ## **2) Multiple Linear Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
multiple_model = LinearRegression()
multiple_model.fit(X,y)
multiple_model.score(X,y)
# Out:
# 0.9873390449817324

# %%
print(multiple_model.intercept_)
print(multiple_model.coef_)
# Out:
# 5.4232585371578605e-18
# [ 1.03030448  0.04849185 -0.00247149  0.03088417  0.00355072 -0.00355072
#   0.00169651 -0.00266439 -0.00220437]

# %%
Xs = sm.add_constant(X)
results = sm.OLS(y, Xs).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.987
# Model:                                  OLS   Adj. R-squared:                  0.987
# Method:                       Least Squares   F-statistic:                 9.344e+05
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:43:01   Log-Likelihood:                 73404.
# No. Observations:                     95868   AIC:                        -1.468e+05
# Df Residuals:                         95859   BIC:                        -1.467e+05
# Df Model:                                 8
# Covariance Type:                  nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 9.476e-17      0.000   2.61e-13      1.000      -0.001       0.001
# Temperature (C)          1.0303      0.001   1709.130      0.000       1.029       1.031
# Humidity                 0.0485      0.001     94.398      0.000       0.047       0.049
# Visibility (km)         -0.0025      0.000     -5.979      0.000      -0.003      -0.002
# Pressure (millibars)     0.0309      0.000     76.027      0.000       0.030       0.032
# precip__rain             0.0036      0.000     15.487      0.000       0.003       0.004
# precip__snow            -0.0036      0.000    -15.487      0.000      -0.004      -0.003
# Hour                     0.0017      0.000      4.600      0.000       0.001       0.002
# Month                   -0.0027      0.000     -6.872      0.000      -0.003      -0.002
# Year                    -0.0022      0.000     -6.004      0.000      -0.003      -0.001
# ==============================================================================
# Omnibus:                     1250.967   Durbin-Watson:                   0.441
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2253.506
# Skew:                          -0.052   Prob(JB):                         0.00
# Kurtosis:                       3.744   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.95e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## **4) Support Vector Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
svr_model = SVR(kernel='linear', C=1.0, epsilon=0.2)
svr_model.fit(X,y)
svr_model.score(X,y)
# Out:
# 0.986039448651997

# %%
print(svr_model.intercept_)
print(svr_model.coef_)
# Out:
# [-0.02540741]
# [[ 1.01622881  0.03795886 -0.01426316  0.02987749 -0.00242462  0.00242462
#    0.00131619 -0.00430354  0.00113982]]

# %%
M = X.shape[1] # number of columns
N = len(df) # number of rows
R2 = svr_model.score(X,y)

# %%
R2_adj = 1-(1-R2)*((N-1) / (N-M-1))
R2_adj
# Out:
# 0.9860381379115045

# %% [markdown]
# > ## **Same results as above, maybe the suitable evaluation metric for the problem has the final word between models.**

# %% [markdown]
# # **D) Temperature, Humidity, Visibility, Pressure, Precip Type, Hour, Month, Year**

# %% [markdown]
# > ## **Using most of the features in the dataframe**

# %%
features = ['Temperature (C)', 'Humidity', 'Visibility (km)', 'Pressure (millibars)', 'precip__rain', 'precip__snow', 'Hour', 'Month', 'Year', 'summary_Breezy and Mostly Cloudy',
       'summary_Breezy and Overcast', 'summary_Breezy and Partly Cloudy',
       'summary_Clear', 'summary_Foggy', 'summary_Mostly Cloudy',
       'summary_Overcast', 'summary_Partly Cloudy']

# %% [markdown]
# ## **2) Multiple Linear Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
multiple_model = LinearRegression()
multiple_model.fit(X,y)
multiple_model.score(X,y)
# Out:
# 0.987657138683554

# %%
print(multiple_model.intercept_)
print(multiple_model.coef_)
# Out:
# 6.652722339722468e-19
# [ 1.02570167e+00  4.63908299e-02  1.71874780e-03  2.67660896e-02
#   4.36709587e-03 -4.36709587e-03  2.00965054e-03 -2.49798451e-03
#  -2.38643630e-03 -5.21465475e-03 -1.19822000e-02 -5.92389392e-03
#   2.66251409e-03  9.03733791e-03  7.73797363e-04 -6.44233633e-03
#   1.08493265e-03]

# %%
Xs = sm.add_constant(X)
results = sm.OLS(y, Xs).fit()
print(results.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.988
# Model:                                  OLS   Adj. R-squared:                  0.988
# Method:                       Least Squares   F-statistic:                 5.113e+05
# Date:                      Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                              19:45:47   Log-Likelihood:                 74624.
# No. Observations:                     95868   AIC:                        -1.492e+05
# Df Residuals:                         95852   BIC:                        -1.491e+05
# Df Model:                                15
# Covariance Type:                  nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             9.476e-17      0.000   2.64e-13      1.000      -0.001       0.001
# Temperature (C)                      1.0257      0.001   1687.528      0.000       1.025       1.027
# Humidity                             0.0464      0.001     89.204      0.000       0.045       0.047
# Visibility (km)                      0.0017      0.000      3.537      0.000       0.001       0.003
# Pressure (millibars)                 0.0268      0.000     64.423      0.000       0.026       0.028
# precip__rain                         0.0044      0.000     19.175      0.000       0.004       0.005
# precip__snow                        -0.0044      0.000    -19.175      0.000      -0.005      -0.004
# Hour                                 0.0020      0.000      5.505      0.000       0.001       0.003
# Month                               -0.0025      0.000     -6.518      0.000      -0.003      -0.002
# Year                                -0.0024      0.000     -6.536      0.000      -0.003      -0.002
# summary_Breezy and Mostly Cloudy    -0.0052      0.000    -14.551      0.000      -0.006      -0.005
# summary_Breezy and Overcast         -0.0120      0.000    -33.371      0.000      -0.013      -0.011
# summary_Breezy and Partly Cloudy    -0.0059      0.000    -16.514      0.000      -0.007      -0.005
# summary_Clear                        0.0027      0.000      8.304      0.000       0.002       0.003
# summary_Foggy                        0.0090      0.000     21.482      0.000       0.008       0.010
# summary_Mostly Cloudy                0.0008      0.000      2.891      0.004       0.000       0.001
# summary_Overcast                    -0.0064      0.000    -20.966      0.000      -0.007      -0.006
# summary_Partly Cloudy                0.0011      0.000      3.820      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                      992.499   Durbin-Watson:                   0.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1691.699
# Skew:                           0.029   Prob(JB):                         0.00
# Kurtosis:                       3.648   Cond. No.                     2.21e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.81e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## **4) Support Vector Regression**

# %%
X = scaled_df[features]
y = scaled_df['Apparent Temperature (C)']

# %%
svr_model = SVR(kernel='linear', C=1.0, epsilon=0.2)
svr_model.fit(X,y)
svr_model.score(X,y)
# Out:
# 0.9866849243977803

# %%
print(svr_model.intercept_)
print(svr_model.coef_)
# Out:
# [-0.01947997]
# [[ 1.01457905  0.03920318 -0.01315103  0.02685458 -0.00165341  0.00165341
#    0.00163125 -0.00342303  0.00112229 -0.00321152 -0.00714983 -0.00398822
#    0.00371962  0.00138549 -0.00102243 -0.00665634  0.0052217 ]]

# %%
M = X.shape[1] # number of columns
N = len(df) # number of rows
R2 = svr_model.score(X,y)

# %%
R2_adj = 1-(1-R2)*((N-1) / (N-M-1))
R2_adj
# Out:
# 0.9866825628298592

# %% [markdown]
# > ## **SVR is taking large time running when facing too many features, so model 2 is better overall as there is no difference.**

# %% [markdown]
# > ### **There is no difference when trying different metrics**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y, multiple_model.predict(X))
# Out:
# 0.08527375213116725

# %%
mean_absolute_error(y, svr_model.predict(X))
# Out:
# 0.09270878121565022

# %%
mean_squared_error(y, multiple_model.predict(X))
# Out:
# 0.012342861316445986

# %%
mean_squared_error(y, svr_model.predict(X))
# Out:
# 0.013315075602219626

# %% [markdown]
# > ### *We can try other methods like mapping numerical features with categories such as temperature can be categorized for patterns in <=10, >= 27 or visibility in > 12, <= 13.5. Also we can map features like hour to two features day and night based on hour value and month to four categories of seasons and more but the actual found features are performing well until now.*

# %% [markdown]
# ---
